# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import pprint
import random

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
#cities = ['amderma', 'victoria', 'rocha']
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# set up lists to hold reponse info
cities_list = []
cloudiness_list = []
countries = []
dates = []
humidity_list = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
counter = 1
set_counter = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        print(city)
        print(f"Processing record {counter} of Set {set_counter} | {city}")
        response = requests.get(query_url + city).json()
        #pprint.pprint(response)
        cities_list.append(response['name'])
        countries.append(response['sys']['country'])
        cloudiness_list.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity_list.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        
    # Handle exceptions for a character that is not available in the Star Wars API
    except Exception as exp: 
        # Append null values
        print("City not found, skipping...", exp)
        pass
    counter = counter + 1
    if counter % 50 == 0:
        set_counter = set_counter + 1
        print(set_counter)
        counter = 1
    
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# avarua
# Processing record 1 of Set 1 | avarua
# beira
# Processing record 2 of Set 1 | beira
# carnarvon
# Processing record 3 of Set 1 | carnarvon
# qaanaaq
# Processing record 4 of Set 1 | qaanaaq
# longyearbyen
# Processing record 5 of Set 1 | longyearbyen
# kaitangata
# Processing record 6 of Set 1 | kaitangata
# samarai
# Processing record 7 of Set 1 | samarai
# mathbaria
# Processing record 8 of Set 1 | mathbaria
# hilo
# Processing record 9 of Set 1 | hilo
# ushuaia
# Processing record 10 of Set 1 | ushuaia
# fortuna
# Processing record 11 of Set 1 | fortuna
# hermanus
# Processing record 12 of Set 1 | hermanus
# namibe
# Processing record 13 of Set 1 | namibe
# geraldton
# Processing record 14 of Set 1 | geraldton
# mataura
# Processing record 15 of Set 1 | mataura
# jamestown
# Processing record 16 of Set 1 | jamestown
# clyde river
# Processing record 17 of Set 1 | clyde river
# yellowknife
# Processing record 18 of Set 1 | yellowknife
# the valley
# Processing record 19 of Set 1 | the valley
# mogocha
# Processing record 20 of Set 1 | mogocha
# nikolskoye
# Processing record 21 of Set 1 | nikolskoye
# taltal
# Processing record 22 of Set 1 | taltal
# vaini
# Processing record 23 of Set 1 | vaini
# leningradskiy
# Processing record 24 of Set 1 | leningradskiy
# katherine
# Processing record 25 of Set 1 | katherine
# siderno
# Processing record 26 of Set 1 | siderno
# tiksi
# Processing record 27 of Set 1 | tiksi
# aykhal
# Processing record 28 of Set 1 | aykhal
# riyadh
# Processing record 29 of Set 1 | riyadh
# ucluelet
# Processing record 30 of Set 1 | ucluelet
# conde
# Processing record 31 of Set 1 | conde
# shingu
# Processing record 32 of Set 1 | shingu
# pervomayskoye
# Processing record 33 of Set 1 | pervomayskoye
# kimbe
# Processing record 34 of Set 1 | kimbe
# taolanaro
# Processing record 35 of Set 1 | taolanaro
# City not found, skipping... 'name'
# sentyabrskiy
# Processing record 36 of Set 1 | sentyabrskiy
# City not found, skipping... 'name'
# elko
# Processing record 37 of Set 1 | elko
# acapulco
# Processing record 38 of Set 1 | acapulco
# ambon
# Processing record 39 of Set 1 | ambon
# vardo
# Processing record 40 of Set 1 | vardo
# luderitz
# Processing record 41 of Set 1 | luderitz
# palabuhanratu
# Processing record 42 of Set 1 | palabuhanratu
# City not found, skipping... 'name'
# lakhdenpokhya
# Processing record 43 of Set 1 | lakhdenpokhya
# lardos
# Processing record 44 of Set 1 | lardos
# lakatoro
# Processing record 45 of Set 1 | lakatoro
# upernavik
# Processing record 46 of Set 1 | upernavik
# kavieng
# Processing record 47 of Set 1 | kavieng
# tasiilaq
# Processing record 48 of Set 1 | tasiilaq
# iracoubo
# Processing record 49 of Set 1 | iracoubo
# 2
# yinchuan
# Processing record 1 of Set 2 | yinchuan
# samusu
# Processing record 2 of Set 2 | samusu
# City not found, skipping... 'name'
# sao joao del rei
# Processing record 3 of Set 2 | sao joao del rei
# tuktoyaktuk
# Processing record 4 of Set 2 | tuktoyaktuk
# tiarei
# Processing record 5 of Set 2 | tiarei
# puerto ayora
# Processing record 6 of Set 2 | puerto ayora
# akdepe
# Processing record 7 of Set 2 | akdepe
# arraial do cabo
# Processing record 8 of Set 2 | arraial do cabo
# mys shmidta
# Processing record 9 of Set 2 | mys shmidta
# City not found, skipping... 'name'
# vaitupu
# Processing record 10 of Set 2 | vaitupu
# City not found, skipping... 'name'
# carutapera
# Processing record 11 of Set 2 | carutapera
# albany
# Processing record 12 of Set 2 | albany
# shahr-e kord
# Processing record 13 of Set 2 | shahr-e kord
# lorengau
# Processing record 14 of Set 2 | lorengau
# yunyang
# Processing record 15 of Set 2 | yunyang
# ponta do sol
# Processing record 16 of Set 2 | ponta do sol
# punta arenas
# Processing record 17 of Set 2 | punta arenas
# kruisfontein
# Processing record 18 of Set 2 | kruisfontein
# torbay
# Processing record 19 of Set 2 | torbay
# new norfolk
# Processing record 20 of Set 2 | new norfolk
# morros
# Processing record 21 of Set 2 | morros
# inhambane
# Processing record 22 of Set 2 | inhambane
# cabo san lucas
# Processing record 23 of Set 2 | cabo san lucas
# rikitea
# Processing record 24 of Set 2 | rikitea
# faanui
# Processing record 25 of Set 2 | faanui
# xining
# Processing record 26 of Set 2 | xining
# garowe
# Processing record 27 of Set 2 | garowe
# adrar
# Processing record 28 of Set 2 | adrar
# enshi
# Processing record 29 of Set 2 | enshi
# hovd
# Processing record 30 of Set 2 | hovd
# korla
# Processing record 31 of Set 2 | korla
# mar del plata
# Processing record 32 of Set 2 | mar del plata
# severo-kurilsk
# Processing record 33 of Set 2 | severo-kurilsk
# cape town
# Processing record 34 of Set 2 | cape town
# hobyo
# Processing record 35 of Set 2 | hobyo
# chokurdakh
# Processing record 36 of Set 2 | chokurdakh
# port lincoln
# Processing record 37 of Set 2 | port lincoln
# amderma
# Processing record 38 of Set 2 | amderma
# City not found, skipping... 'name'
# kirensk
# Processing record 39 of Set 2 | kirensk
# aksu
# Processing record 40 of Set 2 | aksu
# sao filipe
# Processing record 41 of Set 2 | sao filipe
# port blair
# Processing record 42 of Set 2 | port blair
# ribeira grande
# Processing record 43 of Set 2 | ribeira grande
# saskylakh
# Processing record 44 of Set 2 | saskylakh
# bredasdorp
# Processing record 45 of Set 2 | bredasdorp
# hobart
# Processing record 46 of Set 2 | hobart
# muswellbrook
# Processing record 47 of Set 2 | muswellbrook
# sambava
# Processing record 48 of Set 2 | sambava
# ola
# Processing record 49 of Set 2 | ola
# 3
# huilong
# Processing record 1 of Set 3 | huilong
# kapaa
# Processing record 2 of Set 3 | kapaa
# ancud
# Processing record 3 of Set 3 | ancud
# olinda
# Processing record 4 of Set 3 | olinda
# dikson
# Processing record 5 of Set 3 | dikson
# esperance
# Processing record 6 of Set 3 | esperance
# busselton
# Processing record 7 of Set 3 | busselton
# shibarghan
# Processing record 8 of Set 3 | shibarghan
# City not found, skipping... 'name'
# cidreira
# Processing record 9 of Set 3 | cidreira
# nelson bay
# Processing record 10 of Set 3 | nelson bay
# qaqortoq
# Processing record 11 of Set 3 | qaqortoq
# faya
# Processing record 12 of Set 3 | faya
# clarence town
# Processing record 13 of Set 3 | clarence town
# bluff
# Processing record 14 of Set 3 | bluff
# buta
# Processing record 15 of Set 3 | buta
# kasongo-lunda
# Processing record 16 of Set 3 | kasongo-lunda
# maridi
# Processing record 17 of Set 3 | maridi
# dalbandin
# Processing record 18 of Set 3 | dalbandin
# douglas
# Processing record 19 of Set 3 | douglas
# viedma
# Processing record 20 of Set 3 | viedma
# touros
# Processing record 21 of Set 3 | touros
# cuamba
# Processing record 22 of Set 3 | cuamba
# kodiak
# Processing record 23 of Set 3 | kodiak
# isangel
# Processing record 24 of Set 3 | isangel
# kahului
# Processing record 25 of Set 3 | kahului
# georgetown
# Processing record 26 of Set 3 | georgetown
# butaritari
# Processing record 27 of Set 3 | butaritari
# cherskiy
# Processing record 28 of Set 3 | cherskiy
# ketchikan
# Processing record 29 of Set 3 | ketchikan
# atuona
# Processing record 30 of Set 3 | atuona
# souillac
# Processing record 31 of Set 3 | souillac
# erzin
# Processing record 32 of Set 3 | erzin
# kutum
# Processing record 33 of Set 3 | kutum
# illoqqortoormiut
# Processing record 34 of Set 3 | illoqqortoormiut
# City not found, skipping... 'name'
# vao
# Processing record 35 of Set 3 | vao
# ust-kuyga
# Processing record 36 of Set 3 | ust-kuyga
# octeville
# Processing record 37 of Set 3 | octeville
# belushya guba
# Processing record 38 of Set 3 | belushya guba
# City not found, skipping... 'name'
# utica
# Processing record 39 of Set 3 | utica
# karpathos
# Processing record 40 of Set 3 | karpathos
# lompoc
# Processing record 41 of Set 3 | lompoc
# castelldefels
# Processing record 42 of Set 3 | castelldefels
# barrow
# Processing record 43 of Set 3 | barrow
# central point
# Processing record 44 of Set 3 | central point
# saint george
# Processing record 45 of Set 3 | saint george
# port alfred
# Processing record 46 of Set 3 | port alfred
# christchurch
# Processing record 47 of Set 3 | christchurch
# paramonga
# Processing record 48 of Set 3 | paramonga
# flinders
# Processing record 49 of Set 3 | flinders
# 4
# tsihombe
# Processing record 1 of Set 4 | tsihombe
# City not found, skipping... 'name'
# laguna
# Processing record 2 of Set 4 | laguna
# saint-philippe
# Processing record 3 of Set 4 | saint-philippe
# ngukurr
# Processing record 4 of Set 4 | ngukurr
# City not found, skipping... 'name'
# san francisco
# Processing record 5 of Set 4 | san francisco
# acajutla
# Processing record 6 of Set 4 | acajutla
# omsk
# Processing record 7 of Set 4 | omsk
# znamenskoye
# Processing record 8 of Set 4 | znamenskoye
# bethel
# Processing record 9 of Set 4 | bethel
# saldanha
# Processing record 10 of Set 4 | saldanha
# labrea
# Processing record 11 of Set 4 | labrea
# esmeraldas
# Processing record 12 of Set 4 | esmeraldas
# soyo
# Processing record 13 of Set 4 | soyo
# yulara
# Processing record 14 of Set 4 | yulara
# necochea
# Processing record 15 of Set 4 | necochea
# riverton
# Processing record 16 of Set 4 | riverton
# udachnyy
# Processing record 17 of Set 4 | udachnyy
# abu kamal
# Processing record 18 of Set 4 | abu kamal
# kota belud
# Processing record 19 of Set 4 | kota belud
# lata
# Processing record 20 of Set 4 | lata
# cap malheureux
# Processing record 21 of Set 4 | cap malheureux
# buin
# Processing record 22 of Set 4 | buin
# vanderhoof
# Processing record 23 of Set 4 | vanderhoof
# shitanjing
# Processing record 24 of Set 4 | shitanjing
# saleaula
# Processing record 25 of Set 4 | saleaula
# City not found, skipping... 'name'
# pangnirtung
# Processing record 26 of Set 4 | pangnirtung
# vestmanna
# Processing record 27 of Set 4 | vestmanna
# narsaq
# Processing record 28 of Set 4 | narsaq
# litoral del san juan
# Processing record 29 of Set 4 | litoral del san juan
# City not found, skipping... 'name'
# marsabit
# Processing record 30 of Set 4 | marsabit
# haines junction
# Processing record 31 of Set 4 | haines junction
# pevek
# Processing record 32 of Set 4 | pevek
# middelburg
# Processing record 33 of Set 4 | middelburg
# brae
# Processing record 34 of Set 4 | brae
# mount gambier
# Processing record 35 of Set 4 | mount gambier
# los llanos de aridane
# Processing record 36 of Set 4 | los llanos de aridane
# coahuayana
# Processing record 37 of Set 4 | coahuayana
# phan rang
# Processing record 38 of Set 4 | phan rang
# City not found, skipping... 'name'
# sao joao da barra
# Processing record 39 of Set 4 | sao joao da barra
# nelson
# Processing record 40 of Set 4 | nelson
# richards bay
# Processing record 41 of Set 4 | richards bay
# aklavik
# Processing record 42 of Set 4 | aklavik
# victoria
# Processing record 43 of Set 4 | victoria
# dickinson
# Processing record 44 of Set 4 | dickinson
# auki
# Processing record 45 of Set 4 | auki
# ahipara
# Processing record 46 of Set 4 | ahipara
# indianola
# Processing record 47 of Set 4 | indianola
# maha sarakham
# Processing record 48 of Set 4 | maha sarakham
# kurilsk
# Processing record 49 of Set 4 | kurilsk
# 5
# nizhneyansk
# Processing record 1 of Set 5 | nizhneyansk
# City not found, skipping... 'name'
# acarau
# Processing record 2 of Set 5 | acarau
# vila franca do campo
# Processing record 3 of Set 5 | vila franca do campo
# kobojango
# Processing record 4 of Set 5 | kobojango
# City not found, skipping... 'name'
# kinlochleven
# Processing record 5 of Set 5 | kinlochleven
# mehrabpur
# Processing record 6 of Set 5 | mehrabpur
# salalah
# Processing record 7 of Set 5 | salalah
# siswa bazar
# Processing record 8 of Set 5 | siswa bazar
# bagdarin
# Processing record 9 of Set 5 | bagdarin
# port macquarie
# Processing record 10 of Set 5 | port macquarie
# salamiyah
# Processing record 11 of Set 5 | salamiyah
# ayagoz
# Processing record 12 of Set 5 | ayagoz
# vaitape
# Processing record 13 of Set 5 | vaitape
# bonavista
# Processing record 14 of Set 5 | bonavista
# chimbote
# Processing record 15 of Set 5 | chimbote
# valparaiso
# Processing record 16 of Set 5 | valparaiso
# te anau
# Processing record 17 of Set 5 | te anau
# nikolayevka
# Processing record 18 of Set 5 | nikolayevka
# bolungarvik
# Processing record 19 of Set 5 | bolungarvik
# City not found, skipping... 'name'
# tura
# Processing record 20 of Set 5 | tura
# khatanga
# Processing record 21 of Set 5 | khatanga
# ardrossan
# Processing record 22 of Set 5 | ardrossan
# greenlaw
# Processing record 23 of Set 5 | greenlaw
# nizhniy kuranakh
# Processing record 24 of Set 5 | nizhniy kuranakh
# caborca
# Processing record 25 of Set 5 | caborca
# sarangani
# Processing record 26 of Set 5 | sarangani
# port elizabeth
# Processing record 27 of Set 5 | port elizabeth
# alexandria
# Processing record 28 of Set 5 | alexandria
# bulgan
# Processing record 29 of Set 5 | bulgan
# oromocto
# Processing record 30 of Set 5 | oromocto
# tutoia
# Processing record 31 of Set 5 | tutoia
# ternate
# Processing record 32 of Set 5 | ternate
# sao felix do xingu
# Processing record 33 of Set 5 | sao felix do xingu
# toftir
# Processing record 34 of Set 5 | toftir
# City not found, skipping... 'name'
# saint-paul
# Processing record 35 of Set 5 | saint-paul
# ayan
# Processing record 36 of Set 5 | ayan
# riohacha
# Processing record 37 of Set 5 | riohacha
# smoky lake
# Processing record 38 of Set 5 | smoky lake
# masuguru
# Processing record 39 of Set 5 | masuguru
# sooke
# Processing record 40 of Set 5 | sooke
# east london
# Processing record 41 of Set 5 | east london
# thompson
# Processing record 42 of Set 5 | thompson
# nome
# Processing record 43 of Set 5 | nome
# santa isabel
# Processing record 44 of Set 5 | santa isabel
# broken hill
# Processing record 45 of Set 5 | broken hill
# helong
# Processing record 46 of Set 5 | helong
# muros
# Processing record 47 of Set 5 | muros
# sohag
# Processing record 48 of Set 5 | sohag
# husavik
# Processing record 49 of Set 5 | husavik
# 6
# parrita
# Processing record 1 of Set 6 | parrita
# aksarka
# Processing record 2 of Set 6 | aksarka
# gamba
# Processing record 3 of Set 6 | gamba
# comodoro rivadavia
# Processing record 4 of Set 6 | comodoro rivadavia
# castro
# Processing record 5 of Set 6 | castro
# sangar
# Processing record 6 of Set 6 | sangar
# abu samrah
# Processing record 7 of Set 6 | abu samrah
# canon city
# Processing record 8 of Set 6 | canon city
# chegutu
# Processing record 9 of Set 6 | chegutu
# tecoanapa
# Processing record 10 of Set 6 | tecoanapa
# wewak
# Processing record 11 of Set 6 | wewak
# padang
# Processing record 12 of Set 6 | padang
# port augusta
# Processing record 13 of Set 6 | port augusta
# tubruq
# Processing record 14 of Set 6 | tubruq
# City not found, skipping... 'name'
# birao
# Processing record 15 of Set 6 | birao
# nanortalik
# Processing record 16 of Set 6 | nanortalik
# elizabeth city
# Processing record 17 of Set 6 | elizabeth city
# krasnovishersk
# Processing record 18 of Set 6 | krasnovishersk
# puerto baquerizo moreno
# Processing record 19 of Set 6 | puerto baquerizo moreno
# pocosol
# Processing record 20 of Set 6 | pocosol
# nuevo progreso
# Processing record 21 of Set 6 | nuevo progreso
# isiro
# Processing record 22 of Set 6 | isiro
# meulaboh
# Processing record 23 of Set 6 | meulaboh
# katsuura
# Processing record 24 of Set 6 | katsuura
# kovur
# Processing record 25 of Set 6 | kovur
# nyurba
# Processing record 26 of Set 6 | nyurba
# broome
# Processing record 27 of Set 6 | broome
# beloha
# Processing record 28 of Set 6 | beloha
# myitkyina
# Processing record 29 of Set 6 | myitkyina
# hithadhoo
# Processing record 30 of Set 6 | hithadhoo
# bajo baudo
# Processing record 31 of Set 6 | bajo baudo
# City not found, skipping... 'name'
# tonder
# Processing record 32 of Set 6 | tonder
# artyk
# Processing record 33 of Set 6 | artyk
# City not found, skipping... 'name'
# angoche
# Processing record 34 of Set 6 | angoche
# guasdualito
# Processing record 35 of Set 6 | guasdualito
# pontes e lacerda
# Processing record 36 of Set 6 | pontes e lacerda
# olafsvik
# Processing record 37 of Set 6 | olafsvik
# perez
# Processing record 38 of Set 6 | perez
# maragogi
# Processing record 39 of Set 6 | maragogi
# mehran
# Processing record 40 of Set 6 | mehran
# khandyga
# Processing record 41 of Set 6 | khandyga
# labutta
# Processing record 42 of Set 6 | labutta
# City not found, skipping... 'name'
# barentsburg
# Processing record 43 of Set 6 | barentsburg
# City not found, skipping... 'name'
# seoul
# Processing record 44 of Set 6 | seoul
# progreso
# Processing record 45 of Set 6 | progreso
# rawatbhata
# Processing record 46 of Set 6 | rawatbhata
# jinka
# Processing record 47 of Set 6 | jinka
# asau
# Processing record 48 of Set 6 | asau
# mahebourg
# Processing record 49 of Set 6 | mahebourg
# 7
# caravelas
# Processing record 1 of Set 7 | caravelas
# saint anthony
# Processing record 2 of Set 7 | saint anthony
# bondo
# Processing record 3 of Set 7 | bondo
# lodwar
# Processing record 4 of Set 7 | lodwar
# havoysund
# Processing record 5 of Set 7 | havoysund
# moerai
# Processing record 6 of Set 7 | moerai
# chardara
# Processing record 7 of Set 7 | chardara
# neiafu
# Processing record 8 of Set 7 | neiafu
# umm lajj
# Processing record 9 of Set 7 | umm lajj
# tripoli
# Processing record 10 of Set 7 | tripoli
# khandbari
# Processing record 11 of Set 7 | khandbari
# grand gaube
# Processing record 12 of Set 7 | grand gaube
# sumbe
# Processing record 13 of Set 7 | sumbe
# abu dhabi
# Processing record 14 of Set 7 | abu dhabi
# kunming
# Processing record 15 of Set 7 | kunming
# hamilton
# Processing record 16 of Set 7 | hamilton
# san cristobal
# Processing record 17 of Set 7 | san cristobal
# dongsheng
# Processing record 18 of Set 7 | dongsheng
# geylegphug
# Processing record 19 of Set 7 | geylegphug
# City not found, skipping... 'name'
# harper
# Processing record 20 of Set 7 | harper
# yerofey pavlovich
# Processing record 21 of Set 7 | yerofey pavlovich
# vagay
# Processing record 22 of Set 7 | vagay
# ciudad bolivar
# Processing record 23 of Set 7 | ciudad bolivar
# pisco
# Processing record 24 of Set 7 | pisco
# lazarev
# Processing record 25 of Set 7 | lazarev
# talalayivka
# Processing record 26 of Set 7 | talalayivka
# utiroa
# Processing record 27 of Set 7 | utiroa
# City not found, skipping... 'name'
# nuqui
# Processing record 28 of Set 7 | nuqui
# skelleftea
# Processing record 29 of Set 7 | skelleftea
# hasaki
# Processing record 30 of Set 7 | hasaki
# sinnamary
# Processing record 31 of Set 7 | sinnamary
# luganville
# Processing record 32 of Set 7 | luganville
# tocopilla
# Processing record 33 of Set 7 | tocopilla
# lang suan
# Processing record 34 of Set 7 | lang suan
# spokane
# Processing record 35 of Set 7 | spokane
# catamarca
# Processing record 36 of Set 7 | catamarca
# bubaque
# Processing record 37 of Set 7 | bubaque
# nakamura
# Processing record 38 of Set 7 | nakamura
# dilla
# Processing record 39 of Set 7 | dilla
# tidore
# Processing record 40 of Set 7 | tidore
# City not found, skipping... 'name'
# tafalla
# Processing record 41 of Set 7 | tafalla
# tabiauea
# Processing record 42 of Set 7 | tabiauea
# City not found, skipping... 'name'
# beringovskiy
# Processing record 43 of Set 7 | beringovskiy
# palmer
# Processing record 44 of Set 7 | palmer
# lerwick
# Processing record 45 of Set 7 | lerwick
# emirdag
# Processing record 46 of Set 7 | emirdag
# cannington
# Processing record 47 of Set 7 | cannington
# malanje
# Processing record 48 of Set 7 | malanje
# norman wells
# Processing record 49 of Set 7 | norman wells
# 8
# belaya kholunitsa
# Processing record 1 of Set 8 | belaya kholunitsa
# douentza
# Processing record 2 of Set 8 | douentza
# pingliang
# Processing record 3 of Set 8 | pingliang
# novyy svit
# Processing record 4 of Set 8 | novyy svit
# anuradhapura
# Processing record 5 of Set 8 | anuradhapura
# hambantota
# Processing record 6 of Set 8 | hambantota
# grajau
# Processing record 7 of Set 8 | grajau
# puerto leguizamo
# Processing record 8 of Set 8 | puerto leguizamo
# putyatino
# Processing record 9 of Set 8 | putyatino
# ostrovnoy
# Processing record 10 of Set 8 | ostrovnoy
# uk
# Processing record 11 of Set 8 | uk
# City not found, skipping... 'name'
# mezen
# Processing record 12 of Set 8 | mezen
# mae hong son
# Processing record 13 of Set 8 | mae hong son
# paamiut
# Processing record 14 of Set 8 | paamiut
# bahia honda
# Processing record 15 of Set 8 | bahia honda
# airai
# Processing record 16 of Set 8 | airai
# lebu
# Processing record 17 of Set 8 | lebu
# chelmno
# Processing record 18 of Set 8 | chelmno
# kavaratti
# Processing record 19 of Set 8 | kavaratti
# deputatskiy
# Processing record 20 of Set 8 | deputatskiy
# leeton
# Processing record 21 of Set 8 | leeton
# attawapiskat
# Processing record 22 of Set 8 | attawapiskat
# City not found, skipping... 'name'
# safranbolu
# Processing record 23 of Set 8 | safranbolu
# mecca
# Processing record 24 of Set 8 | mecca
# zheleznodorozhnyy
# Processing record 25 of Set 8 | zheleznodorozhnyy
# crestview
# Processing record 26 of Set 8 | crestview
# newport
# Processing record 27 of Set 8 | newport
# tuatapere
# Processing record 28 of Set 8 | tuatapere
# tumannyy
# Processing record 29 of Set 8 | tumannyy
# City not found, skipping... 'name'
# lucapa
# Processing record 30 of Set 8 | lucapa
# bilibino
# Processing record 31 of Set 8 | bilibino
# alekseyevsk
# Processing record 32 of Set 8 | alekseyevsk
# mayo
# Processing record 33 of Set 8 | mayo
# lagoa
# Processing record 34 of Set 8 | lagoa
# villefranche-sur-saone
# Processing record 35 of Set 8 | villefranche-sur-saone
# shache
# Processing record 36 of Set 8 | shache
# mizdah
# Processing record 37 of Set 8 | mizdah
# manturovo
# Processing record 38 of Set 8 | manturovo
# oriximina
# Processing record 39 of Set 8 | oriximina
# tacuarembo
# Processing record 40 of Set 8 | tacuarembo
# setermoen
# Processing record 41 of Set 8 | setermoen
# omsukchan
# Processing record 42 of Set 8 | omsukchan
# kilifi
# Processing record 43 of Set 8 | kilifi
# marcona
# Processing record 44 of Set 8 | marcona
# City not found, skipping... 'name'
# trairi
# Processing record 45 of Set 8 | trairi
# abalak
# Processing record 46 of Set 8 | abalak
# zyryanka
# Processing record 47 of Set 8 | zyryanka
# teguldet
# Processing record 48 of Set 8 | teguldet
# bengkulu
# Processing record 49 of Set 8 | bengkulu
# 9
# yebaishou
# Processing record 1 of Set 9 | yebaishou
# ushtobe
# Processing record 2 of Set 9 | ushtobe
# westport
# Processing record 3 of Set 9 | westport
# san vicente
# Processing record 4 of Set 9 | san vicente
# koumac
# Processing record 5 of Set 9 | koumac
# itarema
# Processing record 6 of Set 9 | itarema
# abay
# Processing record 7 of Set 9 | abay
# kiruna
# Processing record 8 of Set 9 | kiruna
# iralaya
# Processing record 9 of Set 9 | iralaya
# jacareacanga
# Processing record 10 of Set 9 | jacareacanga
# chuy
# Processing record 11 of Set 9 | chuy
# tomatlan
# Processing record 12 of Set 9 | tomatlan
# port shepstone
# Processing record 13 of Set 9 | port shepstone
# dunedin
# Processing record 14 of Set 9 | dunedin
# martapura
# Processing record 15 of Set 9 | martapura
# florida
# Processing record 16 of Set 9 | florida
# oranjemund
# Processing record 17 of Set 9 | oranjemund
# poum
# Processing record 18 of Set 9 | poum
# iquique
# Processing record 19 of Set 9 | iquique
# constitucion
# Processing record 20 of Set 9 | constitucion
# bayan
# Processing record 21 of Set 9 | bayan
# calabozo
# Processing record 22 of Set 9 | calabozo
# marsh harbour
# Processing record 23 of Set 9 | marsh harbour
# trincomalee
# Processing record 24 of Set 9 | trincomalee
# goderich
# Processing record 25 of Set 9 | goderich
# port hardy
# Processing record 26 of Set 9 | port hardy
# yenagoa
# Processing record 27 of Set 9 | yenagoa
# baykit
# Processing record 28 of Set 9 | baykit
# dubbo
# Processing record 29 of Set 9 | dubbo
# palu
# Processing record 30 of Set 9 | palu
# cocobeach
# Processing record 31 of Set 9 | cocobeach
# altoona
# Processing record 32 of Set 9 | altoona
# bud
# Processing record 33 of Set 9 | bud
# churapcha
# Processing record 34 of Set 9 | churapcha
# boguchany
# Processing record 35 of Set 9 | boguchany
# kyra
# Processing record 36 of Set 9 | kyra
# ilulissat
# Processing record 37 of Set 9 | ilulissat
# spirit river
# Processing record 38 of Set 9 | spirit river
# yongan
# Processing record 39 of Set 9 | yongan
# am timan
# Processing record 40 of Set 9 | am timan
# moron
# Processing record 41 of Set 9 | moron
# porto velho
# Processing record 42 of Set 9 | porto velho
# scalea
# Processing record 43 of Set 9 | scalea
# tynda
# Processing record 44 of Set 9 | tynda
# margate
# Processing record 45 of Set 9 | margate
# takoradi
# Processing record 46 of Set 9 | takoradi
# gonen
# Processing record 47 of Set 9 | gonen
# kalmunai
# Processing record 48 of Set 9 | kalmunai
# erdemli
# Processing record 49 of Set 9 | erdemli
# 10
# tautira
# Processing record 1 of Set 10 | tautira
# kostomuksha
# Processing record 2 of Set 10 | kostomuksha
# dordrecht
# Processing record 3 of Set 10 | dordrecht
# twin falls
# Processing record 4 of Set 10 | twin falls
# tombouctou
# Processing record 5 of Set 10 | tombouctou
# pathein
# Processing record 6 of Set 10 | pathein
# ust-tsilma
# Processing record 7 of Set 10 | ust-tsilma
# canalete
# Processing record 8 of Set 10 | canalete
# lichuan
# Processing record 9 of Set 10 | lichuan
# manzhouli
# Processing record 10 of Set 10 | manzhouli
# nam tha
# Processing record 11 of Set 10 | nam tha
# City not found, skipping... 'name'
# fallon
# Processing record 12 of Set 10 | fallon
# magalia
# Processing record 13 of Set 10 | magalia
# placido de castro
# Processing record 14 of Set 10 | placido de castro
# khormuj
# Processing record 15 of Set 10 | khormuj
# City not found, skipping... 'name'
# atar
# Processing record 16 of Set 10 | atar
# bambous virieux
# Processing record 17 of Set 10 | bambous virieux
# kamenka
# Processing record 18 of Set 10 | kamenka
# high level
# Processing record 19 of Set 10 | high level
# caconda
# Processing record 20 of Set 10 | caconda
# aporawan
# Processing record 21 of Set 10 | aporawan
# City not found, skipping... 'name'
# arman
# Processing record 22 of Set 10 | arman
# madisonville
# Processing record 23 of Set 10 | madisonville
# bloomington
# Processing record 24 of Set 10 | bloomington
# pacific grove
# Processing record 25 of Set 10 | pacific grove
# satitoa
# Processing record 26 of Set 10 | satitoa
# City not found, skipping... 'name'
# pallasovka
# Processing record 27 of Set 10 | pallasovka
# yaitepec
# Processing record 28 of Set 10 | yaitepec
# City not found, skipping... 'name'
# rungata
# Processing record 29 of Set 10 | rungata
# City not found, skipping... 'name'
# beibei
# Processing record 30 of Set 10 | beibei
# mastic beach
# Processing record 31 of Set 10 | mastic beach
# navabad
# Processing record 32 of Set 10 | navabad
# City not found, skipping... 'name'
# chissamba
# Processing record 33 of Set 10 | chissamba
# kansanshi
# Processing record 34 of Set 10 | kansanshi
# baghmara
# Processing record 35 of Set 10 | baghmara
# oranjestad
# Processing record 36 of Set 10 | oranjestad
# utrera
# Processing record 37 of Set 10 | utrera
# khani
# Processing record 38 of Set 10 | khani
# aden
# Processing record 39 of Set 10 | aden
# naryan-mar
# Processing record 40 of Set 10 | naryan-mar
# kharod
# Processing record 41 of Set 10 | kharod
# voi
# Processing record 42 of Set 10 | voi
# tual
# Processing record 43 of Set 10 | tual
# invermere
# Processing record 44 of Set 10 | invermere
# esfarayen
# Processing record 45 of Set 10 | esfarayen
# gotsu
# Processing record 46 of Set 10 | gotsu
# puliyankudi
# Processing record 47 of Set 10 | puliyankudi
# udaipur
# Processing record 48 of Set 10 | udaipur
# hoquiam
# Processing record 49 of Set 10 | hoquiam
# 11
# orlik
# Processing record 1 of Set 11 | orlik
# poplar bluff
# Processing record 2 of Set 11 | poplar bluff
# sorland
# Processing record 3 of Set 11 | sorland
# gornopravdinsk
# Processing record 4 of Set 11 | gornopravdinsk
# santa cruz
# Processing record 5 of Set 11 | santa cruz
# berlevag
# Processing record 6 of Set 11 | berlevag
# aquiraz
# Processing record 7 of Set 11 | aquiraz
# banjarmasin
# Processing record 8 of Set 11 | banjarmasin
# maraba
# Processing record 9 of Set 11 | maraba
# krasnoselkup
# Processing record 10 of Set 11 | krasnoselkup
# staryy nadym
# Processing record 11 of Set 11 | staryy nadym
# nuevo ideal
# Processing record 12 of Set 11 | nuevo ideal
# le vauclin
# Processing record 13 of Set 11 | le vauclin
# bhongir
# Processing record 14 of Set 11 | bhongir
# rocha
# Processing record 15 of Set 11 | rocha
# caohe
# Processing record 16 of Set 11 | caohe
# baghdad
# Processing record 17 of Set 11 | baghdad
# petropavlovsk-kamchatskiy
# Processing record 18 of Set 11 | petropavlovsk-kamchatskiy
# oksfjord
# Processing record 19 of Set 11 | oksfjord
# lac du bonnet
# Processing record 20 of Set 11 | lac du bonnet
# masinigudi
# Processing record 21 of Set 11 | masinigudi
# guerrero negro
# Processing record 22 of Set 11 | guerrero negro
# kitui
# Processing record 23 of Set 11 | kitui
# atambua
# Processing record 24 of Set 11 | atambua
# andarab
# Processing record 25 of Set 11 | andarab
# City not found, skipping... 'name'
# grand river south east
# Processing record 26 of Set 11 | grand river south east
# City not found, skipping... 'name'
# taunggyi
# Processing record 27 of Set 11 | taunggyi
# qurayyat
# Processing record 28 of Set 11 | qurayyat
# mount isa
# Processing record 29 of Set 11 | mount isa
# chumikan
# Processing record 30 of Set 11 | chumikan
# ahuimanu
# Processing record 31 of Set 11 | ahuimanu
# noumea
# Processing record 32 of Set 11 | noumea
# itoman
# Processing record 33 of Set 11 | itoman
# chazuta
# Processing record 34 of Set 11 | chazuta
# ballina
# Processing record 35 of Set 11 | ballina
# compostela
# Processing record 36 of Set 11 | compostela
# tres arroyos
# Processing record 37 of Set 11 | tres arroyos
# nur
# Processing record 38 of Set 11 | nur
# uaua
# Processing record 39 of Set 11 | uaua
# codrington
# Processing record 40 of Set 11 | codrington
# egvekinot
# Processing record 41 of Set 11 | egvekinot
# mae sai
# Processing record 42 of Set 11 | mae sai
# santa
# Processing record 43 of Set 11 | santa
# aldan
# Processing record 44 of Set 11 | aldan
# mormugao
# Processing record 45 of Set 11 | mormugao
# belem
# Processing record 46 of Set 11 | belem
# shimoda
# Processing record 47 of Set 11 | shimoda
# iqaluit
# Processing record 48 of Set 11 | iqaluit
# sibolga
# Processing record 49 of Set 11 | sibolga
# 12
# melito di porto salvo
# Processing record 1 of Set 12 | melito di porto salvo
# maldonado
# Processing record 2 of Set 12 | maldonado
# ajaccio
# Processing record 3 of Set 12 | ajaccio
# dingle
# Processing record 4 of Set 12 | dingle
# nabire
# Processing record 5 of Set 12 | nabire
# straelen
# Processing record 6 of Set 12 | straelen
# naze
# Processing record 7 of Set 12 | naze
# shunyi
# Processing record 8 of Set 12 | shunyi
# santa marta
# Processing record 9 of Set 12 | santa marta
# wulanhaote
# Processing record 10 of Set 12 | wulanhaote
# City not found, skipping... 'name'
# biskupiec
# Processing record 11 of Set 12 | biskupiec
# grootfontein
# Processing record 12 of Set 12 | grootfontein
# aginskoye
# Processing record 13 of Set 12 | aginskoye
# zhigansk
# Processing record 14 of Set 12 | zhigansk
# rychnov nad kneznou
# Processing record 15 of Set 12 | rychnov nad kneznou
# rawson
# Processing record 16 of Set 12 | rawson
# san patricio
# Processing record 17 of Set 12 | san patricio
# solnechnyy
# Processing record 18 of Set 12 | solnechnyy
# kongolo
# Processing record 19 of Set 12 | kongolo
# villa bruzual
# Processing record 20 of Set 12 | villa bruzual
# phan thiet
# Processing record 21 of Set 12 | phan thiet
# whitianga
# Processing record 22 of Set 12 | whitianga
# leopoldov
# Processing record 23 of Set 12 | leopoldov
# karratha
# Processing record 24 of Set 12 | karratha
# chapais
# Processing record 25 of Set 12 | chapais
# lolua
# Processing record 26 of Set 12 | lolua
# City not found, skipping... 'name'
# kushima
# Processing record 27 of Set 12 | kushima
# impfondo
# Processing record 28 of Set 12 | impfondo
# osa
# Processing record 29 of Set 12 | osa
# buchanan
# Processing record 30 of Set 12 | buchanan
# leganes
# Processing record 31 of Set 12 | leganes
# japura
# Processing record 32 of Set 12 | japura
# coari
# Processing record 33 of Set 12 | coari
# bathsheba
# Processing record 34 of Set 12 | bathsheba
# sinkat
# Processing record 35 of Set 12 | sinkat
# City not found, skipping... 'name'
# aste
# Processing record 36 of Set 12 | aste
# forestville
# Processing record 37 of Set 12 | forestville
# tigil
# Processing record 38 of Set 12 | tigil
# aasiaat
# Processing record 39 of Set 12 | aasiaat
# quatre cocos
# Processing record 40 of Set 12 | quatre cocos
# sudislavl
# Processing record 41 of Set 12 | sudislavl
# tome
# Processing record 42 of Set 12 | tome
# fort saint john
# Processing record 43 of Set 12 | fort saint john
# City not found, skipping... 'name'
# qasigiannguit
# Processing record 44 of Set 12 | qasigiannguit
# derzhavinsk
# Processing record 45 of Set 12 | derzhavinsk
# lavrentiya
# Processing record 46 of Set 12 | lavrentiya
# aitape
# Processing record 47 of Set 12 | aitape
# akyab
# Processing record 48 of Set 12 | akyab
# kamaishi
# Processing record 49 of Set 12 | kamaishi
# 13
# lalomanu
# Processing record 1 of Set 13 | lalomanu
# City not found, skipping... 'name'
# srednekolymsk
# Processing record 2 of Set 13 | srednekolymsk
# macusani
# Processing record 3 of Set 13 | macusani
# eyl
# Processing record 4 of Set 13 | eyl
# gusau
# Processing record 5 of Set 13 | gusau
# jinxiang
# Processing record 6 of Set 13 | jinxiang
# aras
# Processing record 7 of Set 13 | aras
# porto san giorgio
# Processing record 8 of Set 13 | porto san giorgio
# puerto cabezas
# Processing record 9 of Set 13 | puerto cabezas
# palana
# Processing record 10 of Set 13 | palana
# cayenne
# Processing record 11 of Set 13 | cayenne
# novyy oskol
# Processing record 12 of Set 13 | novyy oskol
# weiser
# Processing record 13 of Set 13 | weiser
# nouadhibou
# Processing record 14 of Set 13 | nouadhibou
# tsabong
# Processing record 15 of Set 13 | tsabong
# coquimbo
# Processing record 16 of Set 13 | coquimbo
# kununurra
# Processing record 17 of Set 13 | kununurra
# primero de enero
# Processing record 18 of Set 13 | primero de enero
# kamenskoye
# Processing record 19 of Set 13 | kamenskoye
# City not found, skipping... 'name'
# minab
# Processing record 20 of Set 13 | minab
# la palma
# Processing record 21 of Set 13 | la palma
# aswan
# Processing record 22 of Set 13 | aswan
# gat
# Processing record 23 of Set 13 | gat
# lubango
# Processing record 24 of Set 13 | lubango
# chaadayevka
# Processing record 25 of Set 13 | chaadayevka
# khawhai
# Processing record 26 of Set 13 | khawhai
# zapolyarnyy
# Processing record 27 of Set 13 | zapolyarnyy
# saint-georges
# Processing record 28 of Set 13 | saint-georges
# bukama
# Processing record 29 of Set 13 | bukama
# jinchang
# Processing record 30 of Set 13 | jinchang
# malakal
# Processing record 31 of Set 13 | malakal
# luanda
# Processing record 32 of Set 13 | luanda
# bemidji
# Processing record 33 of Set 13 | bemidji
# sitka
# Processing record 34 of Set 13 | sitka
# minot
# Processing record 35 of Set 13 | minot
# canavieiras
# Processing record 36 of Set 13 | canavieiras
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create Dataframe
#Create a dataframe to store the data
#print(len(cities_list))
#print(len(countries))
cities_df = pd.DataFrame({'City': cities_list, 'Cloudiness': cloudiness_list, 'Country': countries, 'Date': dates,
                            'Humidity': humidity_list, 'Lat': lats, 'Lng': lngs, 'Max Temp': max_temps, 'Windspeed': wind_speeds})

#Preview the dataframe
cities_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Avarua          90      CK  1595287801        74 -21.21 -159.78
# 1         Beira          40      MZ  1595287801        94 -19.84   34.84
# 2     Carnarvon           0      AU  1595287801        81 -24.87  113.63
# 3       Qaanaaq          99      GL  1595287787        71  77.48  -69.36
# 4  Longyearbyen          75      SJ  1595287801        87  78.22   15.64
#
#    Max Temp  Windspeed
# 0      78.8      19.46
# 1      68.0       4.70
# 2      51.8       8.05
# 3      48.2       1.43
# 4      46.4       3.36

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidites_over_hundred = cities_df[cities_df['Humidity']>100]
indexes_to_drop = humidites_over_hundred.index
print(indexes_to_drop)
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = cities_df.drop(indexes_to_drop, inplace=False)
clean_city_data
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Avarua          90      CK  1595287801        74 -21.21 -159.78
# 1           Beira          40      MZ  1595287801        94 -19.84   34.84
# 2       Carnarvon           0      AU  1595287801        81 -24.87  113.63
# 3         Qaanaaq          99      GL  1595287787        71  77.48  -69.36
# 4    Longyearbyen          75      SJ  1595287801        87  78.22   15.64
# ..            ...         ...     ...         ...       ...    ...     ...
# 572        Luanda          20      AO  1595287875        88  -8.84   13.23
# 573       Bemidji          90      US  1595287911        49  47.47  -94.88
# 574         Sitka          90      US  1595287911        93  57.05 -135.33
# 575         Minot          90      US  1595287898        88  48.23 -101.30
# 576   Canavieiras          29      BR  1595287911        90 -15.68  -38.95
#
#      Max Temp  Windspeed
# 0       78.80      19.46
# 1       68.00       4.70
# 2       51.80       8.05
# 3       48.20       1.43
# 4       46.40       3.36
# ..        ...        ...
# 572     69.80       6.93
# 573     75.00       5.82
# 574     57.20       5.82
# 575     64.40       5.82
# 576     71.51       8.12
#
# [577 rows x 9 columns]

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv
clean_city_data.index.name = 'City_ID'
clean_city_data.head()
clean_city_data.to_csv(output_data_file)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(lats, max_temps, marker="o", facecolors="lightblue", edgecolors="black")
plt.title('City Latitude vs. Max Tempurature (7/20/20)', fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Max Tempurature (f)")

# Save image as PNG
plt.savefig("../Weatherpy Images/Latitude vs. Max Temp 072020.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(lats, humidity_list, marker="o", facecolors="lightblue", edgecolors="black")
plt.title('City Latitude vs. Humidity (7/20/20)', fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save image as PNG
plt.savefig("../Weatherpy Images/Latitude vs. Humidity 072020.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(lats, cloudiness_list, marker="o", facecolors="lightblue", edgecolors="black")
plt.title('City Latitude vs. Cloudiness (7/20/20)', fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save image as PNG
plt.savefig("../Weatherpy Images/Latitude vs. Cloudiness 072020.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(lats, wind_speeds, marker="o", facecolors="lightblue", edgecolors="black")
plt.title('City Latitude vs. Wind Speed (7/20/20)', fontsize=13)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()

# Save image as PNG
plt.savefig("../Weatherpy Images/Latitude vs. Wind Speed 072020.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# Create Northern Hemisphere DataFrame
northern_df = clean_city_data[clean_city_data['Lat'] > 0]
northern_df

# Create Southern Hemisphere DataFrame
southern_df = clean_city_data[clean_city_data['Lat'] < 0]
southern_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# City_ID
# 0             Avarua          90      CK  1595287801        74 -21.21 -159.78
# 1              Beira          40      MZ  1595287801        94 -19.84   34.84
# 2          Carnarvon           0      AU  1595287801        81 -24.87  113.63
# 5         Kaitangata          97      NZ  1595287801        69 -46.28  169.85
# 6            Samarai          88      PG  1595287750        80 -10.62  150.67
# ...              ...         ...     ...         ...       ...    ...     ...
# 558        Kununurra          12      AU  1595287900        21 -15.77  128.73
# 564          Lubango           0      AO  1595287910        45 -14.92   13.49
# 569           Bukama           0      CD  1595287910        47  -9.20   25.85
# 572           Luanda          20      AO  1595287875        88  -8.84   13.23
# 576      Canavieiras          29      BR  1595287911        90 -15.68  -38.95
#
#          Max Temp  Windspeed
# City_ID
# 0           78.80      19.46
# 1           68.00       4.70
# 2           51.80       8.05
# 5           51.33       6.31
# 6           77.49      16.46
# ...           ...        ...
# 558         71.60      12.75
# 564         51.39       4.00
# 569         61.61       2.89
# 572         69.80       6.93
# 576         71.51       8.12
#
# [186 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Max Temp vs Lat in the Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that tempuratures are colder in cities located further north of the equator")
plt.show()
# Out:
# The r-squared is: 0.38882483624386255
# Linear Regression model indicates that tempuratures are colder in cities located further north of the equator

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Max Temp vs Lat in the Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (f)')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that tempuratures are colder in cities located further south of the equator")
plt.show()
# Out:
# The r-squared is: 0.5524251025919459
# Linear Regression model indicates that tempuratures are colder in cities located further south of the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Humidity (%) vs Lat in the Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(46,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that humidity is not influenced by latitude")
plt.show()
# Out:
# The r-squared is: 0.006749114542982826
# Linear Regression model indicates that humidity is not influenced by latitude

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Humidity (%) vs Lat in the Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56,26),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that humidity increases the further south you move from the equator")
plt.show()
# Out:
# The r-squared is: 0.023359221809552504
# Linear Regression model indicates that humidity increases the further south you move from the equator

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Cloudiness (%) vs Lat in the Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that there is no correlation between cloudiness and latitude north of the equator")
plt.show()
# Out:
# The r-squared is: 0.0031106519709495992
# Linear Regression model indicates that there is no correlation between cloudiness and latitude north of the equator

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Cloudiness (%) vs Lat in the Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56,26),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates an increase in humidity as you move further south of the equator")
plt.show()
# Out:
# The r-squared is: 0.05100510911163218
# Linear Regression model indicates an increase in humidity as you move further south of the equator

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Wind Speed (mph) vs Lat in the Northern Hemisphere
x_values = northern_df['Lat']
y_values = northern_df['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that there is no correlation between wind speed and latitude north of the equator")
plt.show()
# Out:
# The r-squared is: 0.0020861652347148635
# Linear Regression model indicates that there is no correlation between wind speed and latitude north of the equator

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot for Wind Speed (mph) vs Lat in the Southern Hemisphere
x_values = southern_df['Lat']
y_values = southern_df['Windspeed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56,23),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Windspeed')
print(f"The r-squared is: {rvalue**2}")
print(f"Linear Regression model indicates that there is no correlation between wind speed and latitude south of the equator")
plt.show()
# Out:
# The r-squared is: 0.004749586989230734
# Linear Regression model indicates that there is no correlation between wind speed and latitude south of the equator
